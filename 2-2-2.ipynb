# %%
import pandas as pd

df = pd.read_csv('data/Fish.csv')

# %%
cond = df['Species'].isin(['Bream', 'Smelt'])
fish_data = df.loc[cond, ['Length2', 'Weight']]

# %%
fish_target = df.loc[cond, ['Species']]

# %%
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
plt.scatter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(cond)
#
# NameError: name 'cond' is not defined

# %%
train_input, test_input, train_target, test_target = \
train_test_split(fish_data, fish_target)

# %%
from sklearn.neighbors import KNeighborsClassifier

kn = KNeighborsClassifier()

kn.fit(train_input, train_target['Species'])
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target['Species'])
# Out:
# 1.0

# %%
kn.predict([[25, 150]])
# Out:
# /Users/manis/Desktop/DAMF2/ml/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Smelt'], dtype=object)

# %%
import matplotlib.pyplot as plt

plt.scatter(train_input['Length2'], train_input['Weight'])
plt.scatter(25, 150, marker='^')

# %%
mean = train_input.mean()
std = train_input.std()
print(mean)
print(std)
# Out:
# Length2     28.147222
# Weight     477.791667
# dtype: float64
# Length2     10.105175
# Weight     319.430817
# dtype: float64

# %%
train_scaled = (train_input - mean) / std
